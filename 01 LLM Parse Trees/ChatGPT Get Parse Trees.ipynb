# %% [markdown]
# ## Get lists from the txt storing parses from ChatGPT

# %%
from ast import literal_eval

def read_file_lines(text_file):
    """
        reads the text_file
        returns a list of uncommented lines
    """
    lists = []
    with open(text_file, 'r') as f:
        for line in f:
            line = line.strip()
            if line.startswith('#'):
                continue  # comment
            lists.append(literal_eval(line))
    return lists

# %% [markdown]
# ## Convert lists into nltk trees

# %%
from nltk.tree import Tree

def get_tree(current_list):
    label = current_list[0]
    subtree_list = []
    
    if len(current_list)>1 and type(current_list[1]) is str:
        return Tree(label, [current_list[1]])        
    
    for i in range(1, len(current_list)):
        subtree_list.append(get_tree(current_list[i]))
    
    return Tree(label, subtree_list)

# %%
def parse_txt(file):
    sent_lists = read_file_lines(file)
    
    tree_list = []
    
    for sentence in sent_lists:
        tree_list.append(get_tree(sentence))
    
    return tree_list

# %% [markdown]
# ### Base

# %%
base_trees_GPT = parse_txt("D:\\MIT\\Courses\\2023-Spring\\6.8630-NLP\\Final Project\\LLM CGW\\ChatGPT\\base-set-parses-2.txt")

# %%
for tree in base_trees_GPT:
    display(tree)
# Out:
# Tree('S', [Tree('NP', [Tree('NNP', ['Arthur'])]), Tree('VP', [Tree('VBD', ['rode']), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NNP', ['Camelot'])])])]), Tree('.', ['.'])])
# Tree('S', [Tree('NP', [Tree('NNP', ['Arthur'])]), Tree('VP', [Tree('VBZ', ['is']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['king'])])]), Tree('.', ['.'])])
# Tree('S', [Tree('NP', [Tree('NNP', ['Arthur'])]), Tree('VP', [Tree('VBZ', ['rides']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['horse'])]), Tree('PP', [Tree('IN', ['near']), Tree('NP', [Tree('DT', ['the']), Tree('NN', ['castle'])])])]), Tree('.', ['.'])])
# Tree('S', [Tree('NP', [Tree('VBG', ['riding']), Tree('PP', [Tree('TO', ['to']), Tree('NP', [Tree('NNP', ['Camelot'])])]), Tree('VBZ', ['is']), Tree('JJ', ['hard'])]), Tree('.', ['.'])])
# Tree('S', [Tree('VB', ['do']), Tree('NP', [Tree('NNS', ['coconuts'])]), Tree('VP', [Tree('VB', ['speak'])]), Tree('?', ['?'])])
# ...

# %%
import pickle

save_dir = "D:\\MIT\\Courses\\2023-Spring\\6.8630-NLP\\Final Project\\LLM CGW\\All Parse Trees\\Trees"

with open(save_dir+'\\ChatGPT_Base_Trees.pkl', 'wb') as f:
    pickle.dump(base_trees_GPT, f)

# %% [markdown]
# ### Adversarial

# %%
adversarial_trees_GPT = parse_txt("D:\\MIT\\Courses\\2023-Spring\\6.8630-NLP\\Final Project\\LLM CGW\\ChatGPT\\adversarial-set-parses-2.txt")

# %%
for tree in adversarial_trees_GPT:
    display(tree)
# Out:
# Tree('S', [Tree('VP', [Tree('VBG', ['being']), Tree('NP', [Tree('VBZ', ['is']), Tree('JJ', ['weary']), Tree('!', ['!'])])])])
# Tree('S', [Tree('NP', [Tree('DT', ['neither']), Tree('DT', ['no']), Tree('NN', ['king']), Tree('VBZ', ['knows']), Tree('CC', ['nor']), Tree('DT', ['no']), Tree('NN', ['chalice']), Tree('VBZ', ['does']), Tree('!', ['!'])])])
# Tree('S', [Tree('NP', [Tree('PRP', ['it'])]), Tree('VP', [Tree('VBZ', ['is']), Tree('NP', [Tree('NP', [Tree('NNP', ['Sir']), Tree('NNP', ['Bedevere'])]), Tree('SBAR', [Tree('WHNP', [Tree('WP', ['who'])]), Tree('S', [Tree('VP', [Tree('VBZ', ['knows']), Tree('NP', [Tree('DT', ['every']), Tree('NN', ['king'])])])])])])]), Tree('!', ['!'])])
# Tree('S', [Tree('VP', [Tree('VB', ['do']), Tree('NP', [Tree('NNS', ['halves'])]), Tree('VP', [Tree('VB', ['ride']), Tree('?', ['?'])])])])
# ...

# %%
import pickle

save_dir = "D:\\MIT\\Courses\\2023-Spring\\6.8630-NLP\\Final Project\\LLM CGW\\All Parse Trees\\Trees"

with open(save_dir+'\\ChatGPT_Adversarial_Trees.pkl', 'wb') as f:
    pickle.dump(adversarial_trees_GPT, f)
